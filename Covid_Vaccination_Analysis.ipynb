# %% [markdown]
# # DSBDAL Mini Project
# ### 31412- Adhish Chindhade<br>31416- Kalyani Dhawade<br>31417- Pratik Dhaygude

# %% [markdown]
# #### Problem Statement:

# %% [markdown]
# #### COVID-19 cases at daily level is present in covid_19_india.csv file<br> Statewise testing details in StatewiseTestingDetails.csv file

# %% [markdown]
# #### Importing modules

# %%
#Import Packages

import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
#read file
covid19India_df = pd.read_csv("covid_19_india.csv" , index_col="Date", parse_dates=True)
covid19India_df
# Out:
#               Sno     Time State/UnionTerritory ConfirmedIndianNational  \
# Date
# 2020-01-30      1  6:00 PM               Kerala                       1
# 2020-01-31      2  6:00 PM               Kerala                       1
# 2020-02-01      3  6:00 PM               Kerala                       2
# 2020-02-02      4  6:00 PM               Kerala                       3
# 2020-02-03      5  6:00 PM               Kerala                       3
# ...           ...      ...                  ...                     ...
# 2021-08-11  18106  8:00 AM            Telangana                       -
# 2021-08-11  18107  8:00 AM              Tripura                       -
# 2021-08-11  18108  8:00 AM          Uttarakhand                       -
# 2021-08-11  18109  8:00 AM        Uttar Pradesh                       -
# 2021-08-11  18110  8:00 AM          West Bengal                       -
#
#            ConfirmedForeignNational    Cured  Deaths  Confirmed
# Date
# ...

# %%
covid19India_df.shape
# Out:
# (18110, 8)

# %%
covid19India_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 18110 entries, 2020-01-30 to 2021-08-11
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Time                      18110 non-null  object
#  2   State/UnionTerritory      18110 non-null  object
#  3   ConfirmedIndianNational   18110 non-null  object
#  4   ConfirmedForeignNational  18110 non-null  object
#  5   Cured                     18110 non-null  int64
#  6   Deaths                    18110 non-null  int64
#  7   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 1.2+ MB

# %%
covid19India_df.head()
# Out:
#             Sno     Time State/UnionTerritory ConfirmedIndianNational  \
# Date
# 2020-01-30    1  6:00 PM               Kerala                       1
# 2020-01-31    2  6:00 PM               Kerala                       1
# 2020-02-01    3  6:00 PM               Kerala                       2
# 2020-02-02    4  6:00 PM               Kerala                       3
# 2020-02-03    5  6:00 PM               Kerala                       3
#
#            ConfirmedForeignNational  Cured  Deaths  Confirmed
# Date
# 2020-01-30                        0      0       0          1
# 2020-01-31                        0      0       0          1
# 2020-02-01                        0      0       0          2
# 2020-02-02                        0      0       0          3
# 2020-02-03                        0      0       0          3

# %% [markdown]
# ### Data Visualization of complete data

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Full dataset")

# Line chart  
sns.lineplot(data=covid19India_df)
# Out:
# <AxesSubplot:title={'center':'Full dataset'}, xlabel='Date'>

# %% [markdown]
# ### How many entries for each state?

# %%
covid19India_df['State/UnionTerritory'].value_counts().sort_values()
# Out:
# Daman & Diu                                   1
# Madhya Pradesh***                             1
# Maharashtra***                                1
# Himanchal Pradesh                             1
# Karanataka                                    1
# Bihar****                                     2
# Dadra and Nagar Haveli                        2
# Unassigned                                    3
# Cases being reassigned to states             60
# Telangana                                   102
# Lakshadweep                                 244
# Telengana                                   426
# Sikkim                                      445
# Nagaland                                    452
# Dadra and Nagar Haveli and Daman and Diu    461
# Meghalaya                                   485
# Tripura                                     492
# Arunachal Pradesh                           496
# Jharkhand                                   498
# Assam                                       498
# ...

# %%
covid19India_df_Haryana = covid19India_df[covid19India_df['State/UnionTerritory']=='Haryana']
covid19India_df_Haryana
covid19India_df_Kerala = covid19India_df[covid19India_df['State/UnionTerritory']=='Kerala']
covid19India_df_Kerala
covid19India_df_WestBengal = covid19India_df[covid19India_df['State/UnionTerritory']=='West Bengal']
covid19India_df_WestBengal
# Out:
#               Sno     Time State/UnionTerritory ConfirmedIndianNational  \
# Date
# 2020-03-18    209  6:00 PM          West Bengal                       1
# 2020-03-19    228  6:00 PM          West Bengal                       1
# 2020-03-20    248  6:00 PM          West Bengal                       2
# 2020-03-21    270  6:00 PM          West Bengal                       3
# 2020-03-22    293  6:00 PM          West Bengal                       4
# ...           ...      ...                  ...                     ...
# 2021-08-07  17966  8:00 AM          West Bengal                       -
# 2021-08-08  18002  8:00 AM          West Bengal                       -
# 2021-08-09  18038  8:00 AM          West Bengal                       -
# 2021-08-10  18074  8:00 AM          West Bengal                       -
# 2021-08-11  18110  8:00 AM          West Bengal                       -
#
#            ConfirmedForeignNational    Cured  Deaths  Confirmed
# Date
# ...

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Haryana dataset")

# Line chart  
sns.lineplot(data=covid19India_df_Haryana)
# Out:
# <AxesSubplot:title={'center':'Haryana dataset'}, xlabel='Date'>

# %%
covid19India_df_by_State = covid19India_df.groupby('State/UnionTerritory')[['Cured','Deaths' ,'Confirmed']].sum().reset_index()
covid19India_df_by_State
# Out:
#                         State/UnionTerritory       Cured    Deaths   Confirmed
# 0                Andaman and Nicobar Islands     1848286     27136     1938498
# 1                             Andhra Pradesh   370426530   2939367   392432753
# 2                          Arunachal Pradesh     6588149     26799     7176907
# 3                                      Assam    92678680    638323    99837011
# 4                                      Bihar   125122902   1093466   132231166
# 5                                  Bihar****     1402468     18881     1430909
# 6           Cases being reassigned to states           0         0      345565
# 7                                 Chandigarh    10117035    147694    10858627
# 8                               Chhattisgarh   151609364   2063920   163776262
# 9                     Dadra and Nagar Haveli       20352         8       20722
# 10  Dadra and Nagar Haveli and Daman and Diu     1841750      1014     1938632
# ...

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Cured")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=covid19India_df_by_State.index, y=covid19India_df_by_State['Cured'])

# Add label for vertical axis
plt.ylabel("Cured")
# Out:
# Text(0, 0.5, 'Cured')

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Confirmed")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=covid19India_df_by_State.index, y=covid19India_df_by_State['Confirmed'])

# Add label for vertical axis
plt.ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Deaths")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=covid19India_df_by_State.index, y=covid19India_df_by_State['Deaths'])

# Add label for vertical axis
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# #### Statewise Data Vaccination

# %%
#read file
fname = 'covid_vaccine_statewise.csv'
vaccine_df = pd.read_csv(("covid_vaccine_statewise.csv"),index_col="Updated On", parse_dates=True )

# %%
vaccine_df.shape
# Out:
# (7845, 23)

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7845 entries, 2021-01-16 to 2021-08-15
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                7845 non-null   object
#  1   Total Doses Administered             7621 non-null   float64
#  2   Sessions                             7621 non-null   float64
#  3    Sites                               7621 non-null   float64
#  4   First Dose Administered              7621 non-null   float64
#  5   Second Dose Administered             7621 non-null   float64
#  6   Male (Doses Administered)            7461 non-null   float64
#  7   Female (Doses Administered)          7461 non-null   float64
#  8   Transgender (Doses Administered)     7461 non-null   float64
#  9    Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
vaccine_df.head()
# Out:
#             State  Total Doses Administered  Sessions   Sites   \
# Updated On
# 2021-01-16  India                   48276.0    3455.0   2957.0
# 2021-01-17  India                   58604.0    8532.0   4954.0
# 2021-01-18  India                   99449.0   13611.0   6583.0
# 2021-01-19  India                  195525.0   17855.0   7951.0
# 2021-01-20  India                  251280.0   25472.0  10504.0
#
#             First Dose Administered  Second Dose Administered  \
# Updated On
# 2021-01-16                  48276.0                       0.0
# 2021-01-17                  58604.0                       0.0
# 2021-01-18                  99449.0                       0.0
# 2021-01-19                 195525.0                       0.0
# 2021-01-20                 251280.0                       0.0
#
#             Male (Doses Administered)  Female (Doses Administered)  \
# Updated On
# 2021-01-16                        NaN                          NaN
# ...

# %%
vaccine_df['State'].unique()
#y
#len(vaccine_df['State'].unique())
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %% [markdown]
# #### Male Vaccination

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Male(Individuals Vaccinated)")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=vaccine_df.index, y=vaccine_df['Male(Individuals Vaccinated)'] )

# Add label for vertical axis
plt.ylabel("Male(Individuals Vaccinated)")
# Out:
# Text(0, 0.5, 'Male(Individuals Vaccinated)')

# %% [markdown]
# ### Female Vaccination

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Female(Individuals Vaccinated)")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=vaccine_df.index, y=vaccine_df['Female(Individuals Vaccinated)'] )

# Add label for vertical axis
plt.ylabel("Female(Individuals Vaccinated)")
# Out:
# Text(0, 0.5, 'Female(Individuals Vaccinated)')
